# %%
import pickle

cache_file = 'weather_cache/buffalo_syracuse_historical.pkl'
with open(cache_file, 'rb') as f:
    weather_data =  pickle.load(f)

# %%
print(weather_data)  # Display the loaded weather data
# Out:
# [{'location': {'lat': 42.5, 'lng': -79.0}, 'data':                         date  temperature_max  temperature_min  \
# 0  2024-02-10 04:00:00+00:00              NaN              NaN
# 1  2024-02-11 04:00:00+00:00              NaN              NaN
# 2  2024-02-12 04:00:00+00:00              NaN              NaN
# 3  2024-02-13 04:00:00+00:00              NaN              NaN
# 4  2024-02-14 04:00:00+00:00              NaN              NaN
# 5  2024-02-15 04:00:00+00:00              NaN              NaN
# 6  2024-02-16 04:00:00+00:00              NaN              NaN
# 7  2024-02-17 04:00:00+00:00              NaN              NaN
# 8  2024-02-18 04:00:00+00:00              NaN              NaN
# 9  2024-02-19 04:00:00+00:00              NaN              NaN
# 10 2024-02-20 04:00:00+00:00              NaN              NaN
#
#     temperature_mean  precipitation_sum  snowfall_sum  rain_sum  humidity_max  \
# 0                NaN                NaN           NaN       NaN           NaN
# ...
